# %% [markdown]
# # Player Recommendation System

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %% [markdown]
# The tools to be used are loaded.

# %%
import time
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity

random.seed(0)

# %% [markdown]
# The csv file containing the football player data is transferred into the notebook.

# %%
df = pd.read_csv("FM 2023.csv")

# %% [markdown]
# The dataset consists of 8452 players and contains 98 columns. These columns provide information about the player's general and football-related characteristics. There are many features under headings such as technical, physical and mental.

# %%
df.shape
# Out:
# (8452, 98)

# %%
df.columns
# Out:
# Index(['Name', 'Position', 'Age', 'ca', 'pa', 'Nationality', 'Club', 'Corners',
#        'Crossing', 'Dribbling', 'Finishing', 'First Touch', 'Free Kick Taking',
#        'Heading', 'Long Shots', 'Long Throws', 'Marking', 'Passing',
#        'Penalty Taking', 'Tackling', 'Technique', 'Aggressiion',
#        'Anticipation', 'Bravery', 'Composure', 'Concentration', 'Vision',
#        'Decision', 'Determination', 'Flair', 'Leadership', 'Off The Ball',
#        'Position.1', 'Teamwork', 'Work Rate', 'Acceleration', 'Agility',
#        'Balance', 'Jumping Reach', 'Natural Fitness', 'Pace', 'Stamina',
#        'Strength', 'Stability', 'Foul', 'Contest performance', 'Injury',
#        'diversity', 'Aerial Reach', 'Command Of Area', 'Communication',
#        'Eccentricity', 'Handling', 'Kicking', 'One On Ones', 'Reflexes',
#        'Rushing Out', 'Punching', 'Throwing', 'Adaptation', 'Ambition',
#        'Argue', 'Loyal', 'Resistant to stress', 'Professional',
# ...

# %% [markdown]
# Columns that will not be used are removed from the data set.

# %%
# Drop unnecessary columns from the DataFrame
df.drop(columns=["Race", "Colour of skin", "UID", "Current reputation",
                 "Domestic reputation", "World reputation"], inplace=True)

# %% [markdown]
# Check which columns have empty values.

# %%
# Generate a Boolean DataFrame indicating missing values
# Calculate the sum of missing values for each column
# Select column names with at least one missing value
df.columns[df.isna().sum() != 0]
# Out:
# Index(['Club', 'Salary', 'Rental club'], dtype='object')

# %% [markdown]
# Players who are without a club have been identified and the club column of these players has been filled in as free player.

# %%
# Replace missing values in the 'Club' column with "Free Player"
df.loc[df['Club'].isnull(), 'Club'] = "Free Player"

# %% [markdown]
# It appears that the players whose salary column is empty are free agents. A prediction model can be developed for this situation.

# %%
# Select the 'Club' column for rows where 'Salary' is null (missing)
df.loc[df['Salary'].isnull(), 'Club']
# Out:
# 822     Free Player
# 1219    Free Player
# 1257    Free Player
# 1325    Free Player
# 1514    Free Player
#            ...
# 7209    Free Player
# 7817    Free Player
# 7868    Free Player
# 8196    Free Player
# 8252    Free Player
# Name: Club, Length: 107, dtype: object

# %% [markdown]
# The rental club column of players playing for their own club is filled in.

# %%
# Replace missing values in the 'Rental club' column with the string "absent"
df.loc[df['Rental club'].isnull(), 'Rental club'] = "absent"

# %% [markdown]
# Long and unnecessary column names have been shortened.

# %%
# Rename selected columns in the DataFrame
df.rename(columns={"Free Kick Taking":"Free_kick", "Penalty Taking":"Penalty", 
                   "Number of national team appearances" : "match_nat_team", 
                   "Goals scored for the national team":"Gol_nat_team"}, inplace=True)

# %%
df
# Out:
#                     Name  Position  Age   ca   pa     Nationality  \
# 0        Kevin De Bruyne  M/AM RLC   31  189  189         Belgium
# 1          Kylian Mbappé   AM/S RL   23  188  197          France
# 2     Robert Lewandowski         S   33  186  190          Poland
# 3         Erling Haaland         S   22  185  195  Norway,England
# 4          Mohamed Salah   AM/S RL   30  185  187           Egypt
# ...                  ...       ...  ...  ...  ...             ...
# 8447          Joe Ashton       D L   16   45  135         England
# 8448          River Ries         S   17   45  135         Germany
# 8449      Halilcan Doğan       D C   23   45  -75          Turkey
# 8450        Adijat Sefer         S   17   45  135         Germany
# 8451         Linus Urban         S   17   45  135         Germany
#
#                             Club  Corners  Crossing  Dribbling  ...  Weight  \
# 0                Manchester City       14        19         15  ...      68
# ...

# %%
# Split the 'Position' column by whitespace, stack the resulting values, and find unique positions
unique_positions = df['Position'].str.split(expand=True).stack().unique()

# Print the unique positions
print(unique_positions)
# Out:
# ['M/AM' 'RLC' 'AM/S' 'RL' 'S' 'C' 'GK' 'D' 'RC' 'M' 'D/DM/M' 'LC' 'DM'
#  'AM' 'L' 'DM/M/AM' 'DM/M' 'D/WB' 'WB/M/AM' 'D/WB/M' 'R' 'D/DM' 'M/AM/S'
#  'D/WB/M/AM' 'WB/AM' 'WB/DM/M/AM' 'D/WB/DM/M' 'D/WB/DM' 'D/WB/DM/M/AM'
#  'D/WB/AM' 'WB/DM/M' 'D/M/AM/S' 'D/M/AM' 'WB/M' 'M/S' 'D/M' 'DM/M/AM/S'
#  'WB/M/AM/S' 'WB' 'D/AM' 'WB/AM/S' 'DM/AM' 'D/S']

# %% [markdown]
# The features are divided into 5 parts: technical, mental, physical, goalkeeping and other.

# %%
# Define lists of football player features grouped by categories
Technical = ['Corners', 'Crossing', 'Dribbling', 'Finishing', 'First Touch',
             'Free_kick', 'Heading', 'Long Shots', 'Long Throws', 'Marking',
             'Passing', 'Penalty', 'Tackling', 'Technique']

Mental = ['Aggressiion', 'Anticipation', 'Bravery', 'Composure', 'Concentration',
          'Vision', 'Decision', 'Determination', 'Flair', 'Leadership', 'Off The Ball',
          'Position.1', 'Teamwork', 'Work Rate']

Physical = ['Acceleration', 'Agility', 'Balance', 'Jumping Reach', 'Natural Fitness', 
            'Pace', 'Stamina', 'Strength']

Goalkeeping = ['Aerial Reach', 'Command Of Area', 'Communication', 'Eccentricity',
               'Handling', 'Kicking', 'One On Ones', 'Reflexes', 'Rushing Out',
               'Punching', 'Throwing']

Other_Feature = ['Stability', 'Foul', 'Contest performance', 'Injury', 'diversity', 
                 'Adaptation', 'Ambition', 'Argue', 'Loyal', 'Resistant to stress',
                 'Professional', 'Sportsmanship', 'Emotional control']

# Create a list containing all the features from different categories
All_features = [Technical + Mental + Physical + Goalkeeping + Other_Feature]

# The 'All_features' list contains all the feature names grouped by categories

# %% [markdown]
# By using the position column, which position the player is better at and on which side of that position is added to the data in separate columns.

# %%
# Extract the best position from the 'Position' column and create a new column 'Best_Position'
best_position = df.Position.apply(lambda x: x.split("/")[0] if '/' in x else (x.split(' ')[0] if ' ' in x else x))
df.insert(2, "Best_Position", best_position)

# %%
# Extract the side information from the 'Position' column and create a new column 'Side'
side = df.Position.apply(lambda x: x.split()[-1] if ' ' in x else "-")
df.insert(3, "Side", side)

# %%
df
# Out:
#                     Name  Position Best_Position Side  Age   ca   pa  \
# 0        Kevin De Bruyne  M/AM RLC             M  RLC   31  189  189
# 1          Kylian Mbappé   AM/S RL            AM   RL   23  188  197
# 2     Robert Lewandowski         S             S    -   33  186  190
# 3         Erling Haaland         S             S    -   22  185  195
# 4          Mohamed Salah   AM/S RL            AM   RL   30  185  187
# ...                  ...       ...           ...  ...  ...  ...  ...
# 8447          Joe Ashton       D L             D    L   16   45  135
# 8448          River Ries         S             S    -   17   45  135
# 8449      Halilcan Doğan       D C             D    C   23   45  -75
# 8450        Adijat Sefer         S             S    -   17   45  135
# 8451         Linus Urban         S             S    -   17   45  135
#
#          Nationality                        Club  Corners  ...  Weight  \
# ...

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Apriori Algorithm

# %%
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# Which features should be good in which positions were determined using the a apriori algorithm.

# %%
def feature_selection(position, side, feature_threshold=10, min_support_threshold=0.8):
    # Define the list of features based on player position (GK or others)
    if position == "GK":
        features = Goalkeeping + Mental + Physical + Other_Feature
    else:
        features = Technical + Mental + Physical + Other_Feature
    
    # Iterate through decreasing min_support_threshold values
    while min_support_threshold >= 0:
        # Filter the DataFrame to select players with the specified position and side
        data = df[(df['Best_Position'] == position) & (df['Side'] == side)][features] > feature_threshold
        
        # Apply the Apriori algorithm to find frequent itemsets
        frequent_itemsets = apriori(data, min_support=min_support_threshold, use_colnames=True)
        
        # Filter itemsets by a minimum length of 10 (you can adjust this threshold)
        frequent_itemsets = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: len(x) > 10)]
        
        # Sort the frequent itemsets by support in descending order
        frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
        
        # Reset the index of the DataFrame
        frequent_itemsets = frequent_itemsets.reset_index(drop=True)
        
        # If any frequent itemsets are found, return the first one
        if len(frequent_itemsets) > 0:
            return frequent_itemsets.itemsets[0]
        else:
            min_support_threshold -= 0.05  # Decrease the threshold

    return None  # Return None if no features are found

# %% [markdown]
# Explanations of position abbreviation

# %% [markdown]
# **GK** - Goalkeeper
# **D** - Defender
# **WB** - Wingback
# **DM** - Defensive Midfielder
# **M** - Midfielder
# **AM** - Attacking Midfielder
# **S** - Striker
#
# **C** - Center
# **L** - Left
# **R** - Right
# **RC** - Right Center
# **LC** - Left Center
# **RL** - Right Left
# **RLC** - Right Left Center

# %% [markdown]
# **GK** - Goalkeeper
# **DL** - Left Fullback (Defender)
# **DC** - Center Back (Defender)
# **DR** - Right Fullback (Defender)
# **WBL** - Left Wingback (Defender/Midfielder)
# **WBR** - Right Wingback (Defender/Midfielder)
# **DM** - Defensive Midfielder
# **ML** - Left Midfielder
# **MC** - Center Midfielder
# **MR** - Right Midfielder
# **AML** - Left Attacking Midfielder
# **AMC** - Center Attacking Midfielder
# **AMR** - Right Attacking Midfielder
# **ST** - Striker

# %%
# Dictionary to map abbreviated positions to their full names
all_position = {"GK": "Goalkeeper", "D": "Defender", "WB": "Wingback", "DM": "Defensive Midfielder",
                "M": "Midfielder", "AM": "Attacking Midfielder", "S": "Striker"}

# Dictionary to map abbreviated sides to their full names
all_side = {"-": "None", "C": "Center", "L": "Left", "R": "Right", "RC": "Right Center",
            "LC": "Left Center", "RL": "Right Left", "RLC": "Right Left Center"}

# %% [markdown]
# The player position and side he/she wants to research are taken as input from the user.

# %%
print("Player Recommendation System")
print("----------Position----------")

# Loop through the available player positions and display them
for pos_ in all_position.keys():
    print(pos_, all_position[pos_])

# Prompt the user to enter the player's position
position = input("Enter the player position:")

# Check if the position is not "GK" (Goalkeeper)
if position != "GK":
    print("----------Side----------")
    
    # Extract unique sides for the specified position and display them
    for side_ in df[df["Best_Position"] == position].Side.unique():
        print(side_, all_side[side_])
    
    # Prompt the user to enter the side of the position
    side = input("Enter the side of position:")
else:
    side = "-"  # For Goalkeepers, set side to "-"
    
# Display the selected player's position and side
print("Player Position:", position, side)
# Out:
# Player Recommendation System
# ----------Position----------
# GK Goalkeeper
# D Defender
# WB Wingback
# DM Defensive Midfielder
# M Midfielder
# AM Attacking Midfielder
# S Striker
# Enter the player position:DM
# ----------Side----------
# C Center
# RLC Right Left Center
# LC Left Center
# RC Right Center
# - None
# Enter the side of position:C
# Player Position: DM C

# %% [markdown]
# Based on the input received from the user, which features are important for the position are determined and the players playing in that position are displayed as separate data.

# %%
def features_and_players(position, side):
    # Use the feature_selection function to find important features
    important_features = feature_selection(position, side)

    # Create a list of selected columns that include important features
    selected_columns = [col for col in list(df.columns) if col not in All_features[0]] + list(important_features)
    
    # Filter the DataFrame to select players with the specified position and side, and only the selected columns
    result_df = df[(df['Best_Position'] == position) & (df['Side'] == side)][selected_columns]
    
    # Return the important features and the resulting DataFrame
    return important_features, result_df

# %%
# Get important features and a filtered DataFrame for the specified position and side
important_features, df_position = features_and_players(position, side)

# Print the important features
print(f"Important Features for {position}{side}:", list(important_features))

# Display the resulting DataFrame
display(df_position)
# Out:
# Important Features for DMC: ['Technique', 'Concentration', 'Work Rate', 'Stamina', 'Anticipation', 'Teamwork', 'First Touch', 'Decision', 'Composure', 'Stability', 'Passing']
#                    Name   Position Best_Position Side  Age   ca   pa  \
# 17                Rodri       DM C            DM    C   26  175  175
# 26               Thiago  DM/M/AM C            DM    C   31  169  173
# 30         N'Golo Kanté     DM/M C            DM    C   31  167  170
# 35           Toni Kroos     DM/M C            DM    C   32  166  176
# 40       İlkay Gündogan  DM/M/AM C            DM    C   31  165  167
# ...                 ...        ...           ...  ...  ...  ...  ...
# 8393     Jack Patterson     DM/M C            DM    C   16   65  -75
# 8394        Diogo Lobão     DM/M C            DM    C   16   65  -75
# 8395       Callum Tripp     DM/M C            DM    C   16   65  -75
# 8409  Valerio Farcomeni  DM/M/AM C            DM    C   16   63  -75
# ...

# %% [markdown]
# ### Content-Based Filtering
# Use player attributes and characteristics to recommend similar players.

# %%
def recommend_similar_players(df, player_name, top_n=5):
    
    # Ensure the player_name exists in the DataFrame
    if player_name not in df['Name'].values:
        raise ValueError("Player name not found in the DataFrame")

    # Find the index of the player
    player_index = df[df['Name'] == player_name].index[0]

    # Specify the important features
    features = list(important_features) + ["Age", "ca"]
    
    # Select only the relevant features
    features_df = df[features]

    # Compute cosine similarity between players
    similarity_matrix = cosine_similarity(features_df)

    # Convert to DataFrame for easier handling
    similarity_df = pd.DataFrame(similarity_matrix, index=df.index, columns=df.index)

    # Get the top N similar players for the specified player_index
    similar_players_indices = similarity_df[player_index].sort_values(ascending=False)[1:top_n+1].index

    # Create a DataFrame with the recommended players and their similarity scores
    recommendations = df.loc[similar_players_indices].copy()
    recommendations['Cosine Similarity'] = similarity_df.loc[similar_players_indices, player_index].values

    return recommendations

# %%
# Input the name of the player you want to find similar players for
input_player = input("Write player name:")

# Call the recommend_similar_players function to get a list of similar players
similar_players = recommend_similar_players(df_position, input_player)

# Display the list of similar players
display(similar_players)
# Out:
# Write player name:Toni Kroos
#                 Name   Position Best_Position Side  Age   ca   pa  \
# 47    Marco Verratti     DM/M C            DM    C   29  164  165
# 532  Tanguy Ndombele     DM/M C            DM    C   25  143  155
# 26            Thiago  DM/M/AM C            DM    C   31  169  173
# 948    Stefano Sensi  DM/M/AM C            DM    C   26  137  150
# 401   Miralem Pjanić     DM/M C            DM    C   32  145  169
#
#                                   Nationality                      Club  GK  \
# 47                                      Italy       Paris Saint-Germain   1
# 532       France,Democratic Republic of Congo         Tottenham Hotspur   1
# 26                               Spain,Brazil                 Liverpool   1
# 948                                     Italy  FC Internazionale Milano   1
# 401  Bosnia and Herzegovina,Luxembourg,France       Sharjah Sports Club   1
#
#      ...  Work Rate  Stamina  Anticipation  Teamwork  First Touch  Decision  \
# ...

# %% [markdown]
# ## Research according to constraints

# %% [markdown]
# Searches can be made according to basic restrictions. This part can be detailed and many features can be added.

# %%
# Define a function called select_player that filters players based on age, value, and salary criteria
def select_player(df, age=df.Age.max(), value=df.Values.max(), salary=df.Salary.max()):
    # Filter the DataFrame to select players based on the specified age, value, and salary criteria
    df = df[(df["Age"] <= age) & (df["Values"] <= value) & (df["Salary"] <= salary)]
    
    # Return the filtered DataFrame
    return df

# %%
# Call the select_player function to create a new DataFrame with filtered players
df_new = select_player(df_position)
df_new
# Out:
#                    Name   Position Best_Position Side  Age   ca   pa  \
# 17                Rodri       DM C            DM    C   26  175  175
# 26               Thiago  DM/M/AM C            DM    C   31  169  173
# 30         N'Golo Kanté     DM/M C            DM    C   31  167  170
# 35           Toni Kroos     DM/M C            DM    C   32  166  176
# 40       İlkay Gündogan  DM/M/AM C            DM    C   31  165  167
# ...                 ...        ...           ...  ...  ...  ...  ...
# 8393     Jack Patterson     DM/M C            DM    C   16   65  -75
# 8394        Diogo Lobão     DM/M C            DM    C   16   65  -75
# 8395       Callum Tripp     DM/M C            DM    C   16   65  -75
# 8409  Valerio Farcomeni  DM/M/AM C            DM    C   16   63  -75
# 8412   Jacopo Simonetta  DM/M/AM C            DM    C   16   62  -75
#
#            Nationality                 Club  GK  ...  Concentration  \
# 17               Spain      Manchester City   1  ...             16
# ...

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Time

# %% [markdown]
# Time is a very important factor in terms of application performance. For this reason, a random side is determined from each position and its time is calculated. Thus, one can get an idea about the general time performance of the application.

# %%
# Initialize an empty dictionary to store processing times for different positions
all_time = {}

# Loop through each position in the 'all_position' dictionary
for position in all_position.keys():
    # Randomly select a side from the unique sides for the current position in the DataFrame
    side = random.choice(df[df["Best_Position"] == position].Side.unique())

    # Record the start time before calling the 'feature_selection' function
    start_time = time.time()

    # Use the 'feature_selection' function to find important features for the current position and side
    features = feature_selection(position, side)

    # Record the end time after the 'feature_selection' function completes
    end_time = time.time()

    # Create a string representing the combination of position and side
    position_side = position + " : " + side

    # Calculate the time taken for feature selection and store it in the dictionary
    all_time[position_side] = end_time - start_time

# %%
# Print the processing times for different positions
print("Processing Times:", all_time)

# Calculate and print the average processing time
average_time = sum(all_time.values()) / len(all_time)
print("\nAverage Time:", average_time)
# Out:
# Processing Times: {'GK : -': 8.210747718811035, 'D : RLC': 0.20544791221618652, 'WB : LC': 0.043109893798828125, 'DM : C': 8.598254919052124, 'M : LC': 0.14857912063598633, 'AM : C': 0.9893677234649658, 'S : RC': 3.277534008026123}
#
# Average Time: 3.0675773280007497

# %% [markdown]
# For positions containing a certain amount of data, the transaction takes approximately 1 second. For positions containing a large amount of data, this time gets longer and approaches 10 seconds.

# %% [markdown]
# ### Cosine Similarity

# %%
display(similar_players["Cosine Similarity"])
# Out:
# 47     0.999640
# 532    0.999398
# 26     0.999390
# 948    0.999372
# 401    0.999348
# Name: Cosine Similarity, dtype: float64

# %% [markdown]
# The values are close to 1, which is the maximum possible value for cosine similarity, suggesting that the two vectors are almost identical in orientation. This shows that the system is working well.

# %% [markdown]
# ### Diversity and Novelty

# %%
# Define a function called evaluate_diversity_and_novelty to assess recommendation diversity and novelty
def evaluate_diversity_and_novelty(df, recommend_function, top_n=5):
    # Counter for keeping track of how many times each player is recommended
    recommendation_counts = Counter()

    # Loop over each player in the DataFrame
    for player in df['Name']:
        # Get top N recommendations for each player using the recommend_function
        recommended_players = recommend_function(df, player, top_n)

        # Update counts based on the recommended players
        recommendation_counts.update(recommended_players['Name'])

    # Convert the recommendation counts to a DataFrame for better visualization
    recommendation_freq_df = pd.DataFrame(recommendation_counts.items(), columns=['Player', 'Recommendation_Count'])
    recommendation_freq_df = recommendation_freq_df.sort_values(by='Recommendation_Count', ascending=False)

    return recommendation_freq_df

# %%
# Evaluate diversity and novelty of recommendations using the evaluate_diversity_and_novelty function
diversity_novelty_df = evaluate_diversity_and_novelty(df_position, recommend_similar_players)

# Display the diversity and novelty DataFrame
display(diversity_novelty_df)
# Out:
#               Player  Recommendation_Count
# 29             André                    22
# 512       Pedro Tiba                    18
# 31         Marc Roca                    17
# 124          Camacho                    17
# 311           Johnny                    17
# ..               ...                   ...
# 90     Victor Jensen                     1
# 613      Fausto Vera                     1
# 789  Jandro Orellana                     1
# 787   Jacopo Da Riva                     1
# 905    Peter Quispel                     1
#
# [906 rows x 2 columns]

# %%
# Calculate the average recommendation count
average_recommendation_count = np.average(diversity_novelty_df.Recommendation_Count)
print(average_recommendation_count)
# Out:
# 5.568432671081678

# %%
# Create a histogram to visualize the distribution of recommendation counts
fig, ax = plt.subplots()

# Calculate the number of bins for the histogram based on the range of recommendation counts
bin_count = diversity_novelty_df['Recommendation_Count'].max() - diversity_novelty_df['Recommendation_Count'].min()

# Plot the histogram
counts, bins, patches = ax.hist(diversity_novelty_df['Recommendation_Count'], bins=bin_count, 
                                edgecolor='black', color="cyan")

# Calculate the mean value and add a red dashed line to the plot
mean_value = diversity_novelty_df['Recommendation_Count'].mean()
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1.5)

# Add text labels to the histogram bars
for count, patch in zip(counts, patches):
    bin_center = (patch.get_x() + patch.get_width() / 2)
    ax.text(bin_center, patch.get_height(), f'{int(count)}', 
            ha='center', va='bottom', color="green", fontsize=9)

# Set labels and title for the histogram
plt.title('Distribution of Player Recommendation')
plt.xlabel('Recommendation Count')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %% [markdown]
# The distribution appears to be centered around the average, indicating that the recommendations are generally consistent for most players. This suggests that the model is utilizing a broad spectrum of players rather than focusing on specific individuals.
